# %%
import pandas as pd
df = pd.DataFrame({
    "name": ["Amna", "Riya"],
    "marks": [80, 90]
})
for i, j in df.iterrows():
    print(j["name"], j["marks"])
# Out:
# Amna 80
# Riya 90

# %%
print(df[df["marks"] > 80])
# Out:
#    name  marks
# 1  Riya     90

# %%
df.loc[2] = ["Riya", 95]
print(df)
# Out:
#    name  marks
# 0  Amna     80
# 1  Riya     90
# 2  Riya     95

# %%
print(df.iloc[0])
# Out:
# name     Amna
# marks      80
# Name: 0, dtype: object

# %%
print(df[["name"]])
# Out:
#    name
# 0  Amna
# 1  Riya
# 2  Riya

# %%
print(df[df["marks"] > 85])
# Out:
#    name  marks
# 1  Riya     90
# 2  Riya     95

# %%
df.loc[2] = ["Kane", 75]
print(df)
# Out:
#    name  marks
# 0  Amna     80
# 1  Riya     90
# 2  Kane     75

# %%
import pandas as pd
df = pd.DataFrame({
    "name": ["Amna", "Riya"],
    "marks": [80, 90]
})
print(df.values.tolist())
# Out:
# [['Amna', 80], ['Riya', 90]]
