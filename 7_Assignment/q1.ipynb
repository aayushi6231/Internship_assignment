# %%
import pandas as pd
data = {"python": 99,
         "java":98, 
         "os":97}

s = pd.Series(data)
print(s)
# Out:
# python    99
# java      98
# os        97
# dtype: int64

# %%
import pandas as pd
marks = [45, 67, 89, 90]

s = pd.Series(marks)
print(s)
# Out:
# 0    45
# 1    67
# 2    89
# 3    90
# dtype: int64

# %%
import pandas as pd
data = [100, 920, 830, 840]

s = pd.Series(data)

print(s[0])
print(s[2])
# Out:
# 100
# 830
