# %%
name = input("Enter name:")
standard = int(input("\nclass:"))

mark1 = int(input("enter mark1 : "))
mark2 = int(input("enter mark2 : ")) 
mark3 = int(input("enter mark3 : "))
mark4 = int(input("enter mark4 : "))
mark5 = int(input("enter mark5 : "))

total_marks =(sum([mark1, mark2, mark3, mark4, mark5]))
print(f"Total_marks = {total_marks}")
Percentage = total_marks/5
print(f" Percentage  = {total_marks/5 }")
# Out:
# Total_marks = 615
#  Percentage  = 123.0

# %%
str1 = input("enter str1: ")
str2 = input("enter str2: ")

final = (f"{str1} {str2}")

print(final)
print(final.lower())
print(final.upper())
print(final.title())
print(final.swapcase())
print(final.capitalize())
print(final.casefold())
print(final.center(30,'*'))
print(final.count('a'))
print(final.endswith('n'))
print(final.find('p'))
print(final.isdigit())
print(final.isalnum())
print(final.isdigit())
print(final.isnumeric())
print(final.isspace())
print(final.replace(str1, str2))
# Out:
# agaASfe WfwegsDas
# agaasfe wfwegsdas
# AGAASFE WFWEGSDAS
# Agaasfe Wfwegsdas
# AGAasFE wFWEGSdAS
# Agaasfe wfwegsdas
# agaasfe wfwegsdas
# ******agaASfe WfwegsDas*******
# 3
# False
# -1
# False
# False
# False
# False
# False
# WfwegsDas WfwegsDas

# %%
if(Percentage >= 60 ):
    print("grade: A")
elif(Percentage >= 50):
    print("grade: B")
elif(Percentage >= 40):
    print("grade: C")
elif(Percentage >= 33):
    print("grade: D")
else: print("fail")
# Out:
# grade: A
