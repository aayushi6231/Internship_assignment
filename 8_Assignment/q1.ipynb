# %%
import pandas as pd
dates = pd.Series([
       "2026-05-26",
       "2026-05-27",
       "2026-05-28",
       "2026-05-29"
])

timeseries = pd.to_datetime(dates)
print(timeseries)
# Out:
# 0   2026-05-26
# 1   2026-05-27
# 2   2026-05-28
# 3   2026-05-29
# dtype: datetime64[ns]
