# %%
# dictionary
d = {"name": "Aayushi", "course": "Python", "marks": 90}

print(d)
print(type(d))

print(d["name"])

d["sname"] = "jain"
print(d)

d["marks"] = 95
print(d)

d.pop("course")
print(d)
# Out:
# {'name': 'Aayushi', 'course': 'Python', 'marks': 90}
# <class 'dict'>
# Aayushi
# {'name': 'Aayushi', 'course': 'Python', 'marks': 90, 'sname': 'jain'}
# {'name': 'Aayushi', 'course': 'Python', 'marks': 95, 'sname': 'jain'}
# {'name': 'Aayushi', 'marks': 95, 'sname': 'jain'}

# %%
# Tuple
a = (10, 20, 30, 40, 50)
print(a)
print(type(a))
print(a[0])
print(a[-1])
print(a[::-1])
print(len(a))
# Out:
# (10, 20, 30, 40, 50)
# <class 'tuple'>
# 10
# 50
# (50, 40, 30, 20, 10)
# 5

# %%
# Set
s = {10, 20, 30, 40}
print(s)
print(type(s))
s.add(50)
print(s)
s.remove(20)
print(s)
s2 = {1, 1, 2, 2, 3, 3}
print(s2)
# Out:
# {40, 10, 20, 30}
# <class 'set'>
# {40, 10, 50, 20, 30}
# {40, 10, 50, 30}
# {1, 2, 3}

# %%
n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))

while (True):

    print("""
    1. Addition
    2. subtraction
    3. multiplication
    4. division
    5. exit
    """)

    ch = int(input("enter your choice: "))

    if ch == 1:
        print("Addition =", n1 + n2)

    elif ch == 2:
        print("Subtraction =", n1 - n2)

    elif ch == 3:
        print("Multiplication =", n1 * n2)

    elif ch == 4:

        if n2 == 0:
            print("Division by zero : error")

        else:
            print("Division =", n1 / n2)

    elif ch == 5:
        break

    else:
        print("wrong choice")
# Out:
#     1. Addition
#     2. subtraction
#     3. multiplication
#     4. division
#     5. exit
#
# Division by zero : error
#
#     1. Addition
#     2. subtraction
#     3. multiplication
#     4. division
#     5. exit

# %%
num = int(input("Enter a number: "))
print(num)

t= num
reverse = 0

while num > 0:

    digit = num % 10
    reverse = reverse * 10 + digit
    num = num // 10

if t== reverse:
    print("Palindrome Num")

else:
    print("Not a Palindrome Num")
# Out:
# 323
# Palindrome Num

# %%
str = input("Enter a string: ")
print(str)

reverse = str[::-1]

if str== reverse:
    print("Palindrome String")

else:
    print("Not a Palindrome String")
# Out:
# str
# Not a Palindrome String
